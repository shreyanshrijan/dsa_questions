# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

iris = load_iris()
df = pd.DataFrame(np.concatenate((iris['data'], np.transpose([iris['target']])), axis=1), columns=[iris['feature_names'] + ['target']])

X_iris = df[['petal length (cm)', 'petal width (cm)']].values
y_iris = df['target'].values

tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf.fit(X_iris, y_iris)
j
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
n = 10
for j in range(1, 10, 2):
    print(j)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
import pandas as pd

df = pd.read_excel('/Users/shreyanshrijan/Downloads/dividends-MFB977-2024_2025.xlsx')
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/dsa_questions/.venv/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
# !pip install openyxl
# Out:
# ERROR: Could not find a version that satisfies the requirement openyxl (from versions: none)
# ERROR: No matching distribution found for openyxl

# %%
# !pip list
# Out:
# Package           Version
# ----------------- -----------
# appnope           0.1.4
# asttokens         2.4.1
# comm              0.2.2
# debugpy           1.8.6
# decorator         5.1.1
# executing         2.1.0
# ipykernel         6.29.5
# ipython           8.28.0
# jedi              0.19.1
# joblib            1.4.2
# jupyter_client    8.6.3
# jupyter_core      5.7.2
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# numpy             2.1.2
# packaging         24.1
# pandas            2.2.3
# parso             0.8.4
# pexpect           4.9.0
# pip               24.2
# platformdirs      4.3.6
# prompt_toolkit    3.0.48
# psutil            6.0.0
# ptyprocess        0.7.0
# pure_eval         0.2.3
# Pygments          2.18.0
# python-dateutil   2.9.0.post0
# pytz              2024.2
# pyzmq             26.2.0
# scikit-learn      1.5.2
# scipy             1.14.1
# six               1.16.0
# stack-data        0.6.3
# threadpoolctl     3.5.0
# tornado           6.4.1
# ...
